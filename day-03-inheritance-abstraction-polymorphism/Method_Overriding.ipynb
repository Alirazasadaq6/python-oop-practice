# %%
class Animal:
    def sound(self):
        print("Animal Sound")

class Dog(Animal):
    def sound(self):
        print("Bark")

animal = Animal()
animal.sound()

dog = Dog()
dog.sound()
# Out:
# Animal Sound
# Bark
