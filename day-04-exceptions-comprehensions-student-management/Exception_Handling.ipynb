# %%
try:
    number = int(input("Please enter your number : "))
    ans = 2/number

except ValueError:
    print("Please enter integer value.")

except ZeroDivisionError:
    print("Zero not allow.")

else:
    print(f"Answer is : {ans}")

finally:
    print("Thank You!")
# Out:
# Please enter your number :  abc
# Please enter integer value.
# Thank You!
