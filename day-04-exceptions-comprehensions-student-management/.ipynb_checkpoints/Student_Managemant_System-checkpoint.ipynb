# %%
import json
class Students:
    def __init__(self):
        pass

    def view_record(self):
        with open("D:\\Apna College\\Learning\\visual_studio\\oop\\students.json","r") as file:
            student = json.load(file)
            for std in student:
                print(f"{std["id"]} - {std["name"]} - {std["department"]}")

    def add_record(self):
        pass

    def search_record(self):
        pass

    def update_record(self):
        pass

    def delete_record(self):
        pass

students = Students()
while(True):
    try:
        print("Please select option.\n1 for view record.\n2 for add record.\n3 for search record.\n4 for update record.\n5 for delete record.\n6 for exit.")
        option = int(input("Please enter your option number : "))

    except ValueError:
        print("Please enter only integer value.")

    else:
        if(option == 1):
            students.view_record()
        elif(option == 2):
            pass
        elif(option == 3):
            pass
        elif(option == 4):
            pass
        elif(option == 5):
            pass
        elif(option == 6):
            print("Thank You!!!")
            break
        else:
            print("Please enter your option between 1 to 6.")
# Out:
# Please select option.
# 1 for view record.
# 2 for add record.
# 3 for search record.
# 4 for update record.
# 5 for delete record.
# 6 for exit.
# Please enter your option number :  1
# 1001
# 1002
# 1003
# 1004
# 1005
# Please select option.
# 1 for view record.
# 2 for add record.
# 3 for search record.
# 4 for update record.
# 5 for delete record.
# 6 for exit.
