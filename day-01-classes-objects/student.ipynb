# %%
class Student:
    def __init__(self,name,age,course,university,marks):
        self.name = name
        self.age = age
        self.course = course
        self.university = university
        self.marks = marks

    def student_details(self):
        print(f"Student name : {self.name}")
        print(f"Student age : {self.age}")
        print(f"Student course: {self.course}")
        print(f"University name: {self.university}")
        

        if self.marks < 0 or self.marks > 100:
            print(f"Please add marks between 0 to 100.")
        elif self.marks >= 0 and self.marks <= 40:
            print(f"Student result : Fail")
        else:
            print(f"Student result : Pass")

    def student_age_update(self):
        self.age = self.age + 1
        print(f"Happy Birthday {self.name}")
        print(f"New age : {self.age}")
    # def student_info(self):
    #     print(f"{self.name} is studying {self.course}")

student1 = Student("Ali Raza", 27,"Computing","Lancashire",100)
student1.student_details()
#student1.student_age_update()
#student1.student_details()
#student1.student_info()

# student2 = Students("Ali Raza", 27,"Computing","Lancashire")
# student2.student_details()
# student2.student_info()

# student3 = Students("Ali Raza", 27,"Computing","Lancashire")
# student3.student_details()
# student3.student_info()
# Out:
# Student name : Ali Raza
# Student age : 27
# Student course: Computing
# University name: Lancashire
# Student result : Pass
